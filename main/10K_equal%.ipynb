# %%
import pandas as pd 
df_10k  = pd.read_csv('acc_data_sampling_50.csv', engine = "python")

# %%
df_fatalk  = pd.read_csv('acc_data_after_cleaning.csv', engine = "python")

# %%
df_fatalk.shape
# Out:
# (186050, 62)

# %%
df_slight1=df_fatalk.query('accident_severity == 3').head(3570)
df_slight1
# Out:
#       vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0                9                        0                 18
# 1               20                        0                  4
# 2                1                        0                  9
# 3                3                        0                  4
# 4                9                        0                 14
# ...            ...                      ...                ...
# 4143             1                        0                 18
# 4144             1                        0                  9
# 4146             1                        0                  9
# 4147             1                        0                 17
# 4148             3                        0                  9
#
#       vehicle_location-restricted_lane  junction_location  \
# 0                                    0                  8
# 1                                    0                  0
# ...

# %%
df_fatalk['accident_severity'].value_counts()
# Out:
# 3    155053
# 2     28161
# 1      2836
# Name: accident_severity, dtype: int64

# %%
df_slight1=df_fatalk.query('accident_severity == 3').head(3750)
df_serious1=df_fatalk.query('accident_severity == 2').head(3750)
df_fatal1 = df_fatalk.query('accident_severity == 1')

# %%
df_slight1=df_10k.query('accident_severity == 3')

# %%
df_fatal1.shape
# Out:
# (2836, 62)

# %%
df_serious_fatal = df_serious1.append(df_fatal1, ignore_index = True)
dff_10k=df_serious_fatal.append(df_slight1,ignore_index=True)

# %%
dff_10k.shape
# Out:
# (10336, 62)

# %%
dff_10k['accident_severity'].value_counts()
# Out:
# 2    3750
# 3    3750
# 1    2836
# Name: accident_severity, dtype: int64

# %%
dff_10k
# Out:
#        vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0                 9                        0                 16
# 1                 1                        0                 18
# 2                 1                        0                 18
# 3                 9                        0                 18
# 4                 5                        0                 13
# ...             ...                      ...                ...
# 10331             3                        0                 18
# 10332             8                        0                 18
# 10333             1                        0                 18
# 10334             1                        0                 17
# 10335             2                        0                 18
#
#        vehicle_location-restricted_lane  junction_location  \
# 0                                     0                  0
# 1                                     0                  8
# ...

# %% [markdown]
# col

# %% [markdown]
# new_col = w['vehicle_type', 'towing_and_articulation', 'vehicle_manoeuvre',
#        'vehicle_location-restricted_lane',
#        'skidding_and_overturning', 'hit_object_in_carriageway',
#        'vehicle_leaving_carriageway', 'hit_object_off_carriageway',
#        '1st_point_of_impact',
#        'journey_purpose_of_driver', 'sex_of_driver', 'age_of_driver',
#        'age_band_of_driver', 'engine_capacity_(cc)', 'propulsion_code',
#        'age_of_vehicle',
#        'NUmber_of_Casualities_unique_to_accident_index',
#        'No_of_Vehicles_involved_unique_to_accident_index', 'accident_severity', 'number_of_vehicles',
#        'number_of_casualties', 'day_of_week', 'time',
#        '1st_road_class', '1st_road_number', 'road_type', 'speed_limit',
#        'junction_detail', 'junction_control', '2nd_road_class',
#        '2nd_road_number', 'pedestrian_crossing-human_control',
#        'pedestrian_crossing-physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'casualty_class', 'sex_of_casualty',
#        'age_of_casualty', 'age_band_of_casualty', 'casualty_severity',
#        'pedestrian_location', 'pedestrian_movement', 'car_passenger',
#        'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker',
#        'casualty_type']

# %% [markdown]
# len(new_col)

# %% [markdown]
# cols_not_in_dataset = set(data.columns) -  set(new_col)

# %% [markdown]
# for col in cols_not_in_dataset:
#     print(col)

# %%
dff_10k
# Out:
#        vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0                 1                        0                 18
# 1                 9                        0                 17
# 2                 9                        0                 18
# 3                 4                        0                 17
# 4                 9                        0                  9
# ...             ...                      ...                ...
# 46204             9                        0                 18
# 46205             9                        0                 15
# 46206             9                        0                 18
# 46207             9                        0                 18
# 46208             1                        0                  7
#
#        vehicle_location-restricted_lane  junction_location  \
# 0                                     0                  0
# 1                                     0                  0
# ...

# %%
dff_10k.to_csv("dff_10k.csv",index = False)
